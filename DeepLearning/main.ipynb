# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.style.use('seaborn-darkgrid')
plt.rcParams['figure.dpi'] = 240

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

def hard_sigmoid(x):
    return np.maximum(np.minimum(0.25*x+0.5, np.ones_like(x)), np.zeros_like(x))

# %%
x = np.linspace(-10, 10, 1000)  # Sample data.

# plt.figure(figsize=(5, 2.7), layout='constrained') #
fig, ax = plt.subplots()
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.

for func in [sigmoid, tanh, hard_sigmoid]:
    ax.plot(x, func(x), label=str(func.__name__))  # Plot some data on the axes.

ax.legend()  # Add a legend.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fcb8cdf79df4> in <module>
#       8
#       9 for func in [sigmoid, tanh, hard_sigmoid]:
# ---> 10     ax.plot(x, func(x), label=str(func.__name__))  # Plot some data on the axes.
#      11
#      12 ax.legend()  # Add a legend.
#
# <ipython-input-21-f4558dde0349> in hard_sigmoid(x)
#       6
#       7 def hard_sigmoid(x):
# ----> 8     return np.max(np.min(0.25*x+0.5, np.ones_like(x)), np.zeros_like(x))
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2877     6
#    2878     """
# -> 2879     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2880                           keepdims=keepdims, initial=initial, where=where)
#    2881
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# Out:
# sigmoid
